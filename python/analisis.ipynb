# %%
import math, subprocess, time, random, os, shutil, sys
import pandas as pd
import numpy as np
from IPython.display import display, clear_output
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

# %% [markdown]
# ## EXPERIMENTO 1

# %%
df_resultados = pd.read_csv("results/result.csv")
df_resultados = df_resultados[(df_resultados["dataset"]=="peor_btf")]
# display(df_resultados[(df_resultados["method"]=="bt")])

title = "Experimento 1"
l = True

plt.xlim(9,35)
plt.ylim(0.01,0.15)
# df_bf = df_resultados[(df_resultados["method"]=="bf")]

df_bt = df_resultados[(df_resultados["method"]=="bt")]

df_bto = df_resultados[(df_resultados["method"]=="bto")]

df_btf = df_resultados[(df_resultados["method"]=="btf")]

df_dp = df_resultados[(df_resultados["method"]=="dp")]

plt.plot()



#puntos
# plt.plot(df_bf["n"],df_bf["time"],l, c="black", label="bf")
plt.plot(df_bt["n"],df_bt["time"],l, c="blue", label="bt")
plt.plot(df_bto["n"],df_bto["time"],l, c="green", label="bto")
plt.plot(df_btf["n"],df_btf["time"],l, c="r", label="btf")
plt.plot(df_dp["n"],df_dp["time"],l, c="purple", label="dp")

handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys())
plt.grid()


plt.title(title)
plt.xlabel('n') 
plt.ylabel('s.')  
plt.show()

# %% [markdown]
# ## EXPERIMENTO 2

# %%
df_resultados = pd.read_csv("results/result.csv")
df_resultados = df_resultados[(df_resultados["dataset"]=="peor_bto")]
# display(df_resultados[(df_resultados["method"]=="bt")])

title = "Experimento 2"
l = True

plt.xlim(9,35)
plt.ylim(-0.0001,0.15)
# df_bf = df_resultados[(df_resultados["method"]=="bf")]

df_bt = df_resultados[(df_resultados["method"]=="bt")]

df_bto = df_resultados[(df_resultados["method"]=="bto")]

df_btf = df_resultados[(df_resultados["method"]=="btf")]

df_dp = df_resultados[(df_resultados["method"]=="dp")]

plt.plot()



#puntos
# plt.plot(df_bf["n"],df_bf["time"],l, c="black", label="bf")
plt.plot(df_bt["n"],df_bt["time"],l, c="blue", label="bt")
plt.plot(df_bto["n"],df_bto["time"],l, c="green", label="bto")
plt.plot(df_btf["n"],df_btf["time"],l, c="r", label="btf")
plt.plot(df_dp["n"],df_dp["time"],l, c="purple", label="dp")

handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys())
plt.grid()


plt.title(title)
plt.xlabel('n') 
plt.ylabel('s.')  
plt.show()

# %%
df_resultados = pd.read_csv("results/result.csv")
df_resultados = df_resultados[(df_resultados["dataset"]=="exp_bt")]
display(df_resultados[(df_resultados["method"]=="bt")])

title = "Experimento 1"
l = True

plt.xlim(9,35)
plt.ylim(-0.0001,0.15)
# df_bf = df_resultados[(df_resultados["method"]=="bf")]

df_bt = df_resultados[(df_resultados["method"]=="bt")]

df_bto = df_resultados[(df_resultados["method"]=="bto")]

df_btf = df_resultados[(df_resultados["method"]=="btf")]

# df_dp = df_resultados[(df_resultados["method"]=="dp")]

plt.plot()



#puntos
# plt.plot(df_bf["n"],df_bf["time"],l, c="black", label="bf")
plt.plot(df_bt["n"],df_bt["time"],l, c="blue", label="bt")
plt.plot(df_bto["n"],df_bto["time"],l, c="green", label="bto")
plt.plot(df_btf["n"],df_btf["time"],l, c="r", label="btf")
# plt.plot(df_dp["n"],df_dp["time"],l, c="purple", label="dp")

handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys())
plt.grid()


plt.title(title)
plt.xlabel('n') 
plt.ylabel('s.')  
plt.show()
# Out:
#     dataset exp_name   n    m method      time
# 713  exp_bt     exp2  10   80     bt  0.017664
# 716  exp_bt     exp5  11   88     bt  0.017755
# 719  exp_bt     exp8  12   96     bt  0.018589
# 722  exp_bt    exp11  13  104     bt  0.019454
# 725  exp_bt    exp14  14  112     bt  0.018163
# 728  exp_bt    exp17  15  120     bt  0.017520
# 731  exp_bt    exp20  16  128     bt  0.017865
# 734  exp_bt    exp23  17  136     bt  0.017843
# 737  exp_bt    exp26  18  144     bt  0.017610
# 740  exp_bt    exp29  19  152     bt  0.016707
# 743  exp_bt    exp32  20  160     bt  0.017189
# 746  exp_bt    exp35  21  168     bt  0.016957
# 749  exp_bt    exp38  22  176     bt  0.017711
# 752  exp_bt    exp41  23  184     bt  0.017938
# 755  exp_bt    exp44  24  192     bt  0.016652
# 758  exp_bt    exp47  25  200     bt  0.018576
# 761  exp_bt    exp50  26  208     bt  0.018360
# 764  exp_bt    exp53  27  216     bt  0.017587
# 767  exp_bt    exp56  28  224     bt  0.019236
# 770  exp_bt    exp59  29  232     bt  0.019595
# 773  exp_bt    exp62  30  240     bt  0.024051

# %%
df_resultados = pd.read_csv("results/result.csv")
df_resultados = df_resultados[(df_resultados["dataset"]=="random")]
# display(df_resultados[(df_resultados["method"]=="bt")])

title = "hola"
l = True

plt.xlim(9,21)
plt.ylim(-0.0001,0.04)
df_bf = df_resultados[(df_resultados["method"]=="bf")]

df_bt = df_resultados[(df_resultados["method"]=="bt")]

df_bto = df_resultados[(df_resultados["method"]=="bto")]

df_btf = df_resultados[(df_resultados["method"]=="btf")]

df_dp = df_resultados[(df_resultados["method"]=="dp")]

plt.plot()



#puntos
plt.plot(df_bf["n"],df_bf["time"],l, c="black", label="bf")
plt.plot(df_bt["n"],df_bt["time"],l, c="blue", label="bt")
plt.plot(df_bto["n"],df_bto["time"],l, c="green", label="bto")
plt.plot(df_btf["n"],df_btf["time"],l, c="r", label="btf")
plt.plot(df_dp["n"],df_dp["time"],l, c="purple", label="dp")

handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys())
plt.grid()


plt.title(title)
plt.xlabel('n') 
plt.ylabel('s.')  
plt.show()

# %% [markdown]
# ## EXPERIMENTO 3

# %%
df_resultados = pd.read_csv("results/result.csv")
df_m1 = df_resultados[(df_resultados["dataset"]=="m_1")]
df_m2 = df_resultados[(df_resultados["dataset"]=="m_2")]
df_m3 = df_resultados[(df_resultados["dataset"]=="m_3")]
df_m4 = df_resultados[(df_resultados["dataset"]=="m_3")]

# %%
df_resultados = df_m4

title = "Experimento 3"
l = ""

# plt.xlim(9,31)
# plt.ylim(0,0.15)

df_dp = df_resultados[(df_resultados["method"]=="dp")]

plt.plot()

plt.plot(df_dp["n"],df_dp["time"],l, c="purple", label="dp")

handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys())
plt.grid()

plt.title(title)
plt.xlabel('n') 
plt.ylabel('s.')  
plt.show()

# %% [markdown]
# ## EXPERIMENTO 4

# %%
df_resultados = pd.read_csv("results/result.csv")
df_n1 = df_resultados[(df_resultados["dataset"]=="n_1")]
df_n2 = df_resultados[(df_resultados["dataset"]=="n_2")]
df_n3 = df_resultados[(df_resultados["dataset"]=="n_3")]
df_n4 = df_resultados[(df_resultados["dataset"]=="n_4")]
# display(df_n1)

# %%
df_resultados = df_n3


title = "Experimento 4"
l = True

# plt.xlim(9,31)
plt.ylim(0,0.15)

df_dp = df_resultados[(df_resultados["method"]=="dp")]

plt.plot()

plt.plot(df_dp["m"],df_dp["time"],l, c="purple", label="dp")

handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys())
plt.grid()

plt.title(title)
plt.xlabel('Limite De Riesgo') 
plt.ylabel('s.')  
plt.show()

# %% [markdown]
# ## EXPERIMENTO PARTICULAR BT

# %%
df_resultados = pd.read_csv("results/result.csv")
df_resultados = df_resultados[(df_resultados["dataset"]=="particular_bt")]

title = "Experimento Backtracking"
l = True

plt.xlim(20,40)
# plt.ylim(-0.0001,0.10)
df_bt = df_resultados[(df_resultados["method"]=="bt")]

df_bto = df_resultados[(df_resultados["method"]=="bto")]

df_btf = df_resultados[(df_resultados["method"]=="btf")]


plt.plot()



#puntos
plt.plot(df_bt["n"],df_bt["time"],l, c="blue", label="bt")
plt.plot(df_bto["n"],df_bto["time"],l, c="green", label="bto")
plt.plot(df_btf["n"],df_btf["time"],l, c="r", label="btf")
# plt.plot(df_dp["n"],df_dp["time"],l, c="purple", label="dp")

handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys())
plt.grid()


plt.title(title)
plt.xlabel('n') 
plt.ylabel('s.')  
plt.show()

# %% [markdown]
# ## EXPERIMENTO FB

# %%
df_resultados = pd.read_csv("results/result.csv")
df_bfr = df_resultados[(df_resultados["dataset"]=="random_bf")]
df_bf1 = df_resultados[(df_resultados["dataset"]=="peor_bto_bf")]
df_bf2 = df_resultados[(df_resultados["dataset"]=="peor_btf_bf")]

x = np.linspace(12, 31, 1000)
y = (2**x)*0.000000017

fig, axis = plt.subplots(1,3,figsize=(18,4))

l = "o"
plt.ylabel('segundos')
plt.xlabel('n')
axis[0].plot(x, y, '--')
axis[1].plot(x, y, '--')
axis[2].plot(x, y, '--')

axis[0].plot(df_bfr["n"],df_bfr["time"],l, c="black", label="bf")
axis[1].plot(df_bf1["n"],df_bf1["time"],l, c="black", label="bf")
axis[2].plot(df_bf2["n"],df_bf2["time"],l, c="black", label="bf")
