# %%
import math, subprocess, time, random, os, shutil, sys
import pandas as pd
import numpy as np
from IPython.display import display, clear_output
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

# %% [markdown]
# ## EXPERIMENTO 1

# %%
df_resultados = pd.read_csv("results/result.csv")
df_resultados = df_resultados[(df_resultados["dataset"]=="peor_btf")]
# display(df_resultados[(df_resultados["method"]=="bt")])

title = "Experimento 1"
l = True

plt.xlim(9,35)
plt.ylim(0.01,0.15)
# df_bf = df_resultados[(df_resultados["method"]=="bf")]

df_bt = df_resultados[(df_resultados["method"]=="bt")]

df_bto = df_resultados[(df_resultados["method"]=="bto")]

df_btf = df_resultados[(df_resultados["method"]=="btf")]

df_dp = df_resultados[(df_resultados["method"]=="dp")]

plt.plot()



#puntos
# plt.plot(df_bf["n"],df_bf["time"],l, c="black", label="bf")
plt.plot(df_bt["n"],df_bt["time"],l, c="blue", label="bt")
plt.plot(df_bto["n"],df_bto["time"],l, c="green", label="bto")
plt.plot(df_btf["n"],df_btf["time"],l, c="r", label="btf")
plt.plot(df_dp["n"],df_dp["time"],l, c="purple", label="dp")

handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys())
plt.grid()


plt.title(title)
plt.xlabel('n') 
plt.ylabel('s.')  
plt.show()

# %% [markdown]
# ## EXPERIMENTO 2

# %%
df_resultados = pd.read_csv("results/result.csv")
df_resultados = df_resultados[(df_resultados["dataset"]=="peor_bto")]
# display(df_resultados[(df_resultados["method"]=="bt")])

title = "Experimento 2"
l = True

plt.xlim(9,35)
plt.ylim(-0.0001,0.15)
# df_bf = df_resultados[(df_resultados["method"]=="bf")]

df_bt = df_resultados[(df_resultados["method"]=="bt")]

df_bto = df_resultados[(df_resultados["method"]=="bto")]

df_btf = df_resultados[(df_resultados["method"]=="btf")]

df_dp = df_resultados[(df_resultados["method"]=="dp")]

plt.plot()



#puntos
# plt.plot(df_bf["n"],df_bf["time"],l, c="black", label="bf")
plt.plot(df_bt["n"],df_bt["time"],l, c="blue", label="bt")
plt.plot(df_bto["n"],df_bto["time"],l, c="green", label="bto")
plt.plot(df_btf["n"],df_btf["time"],l, c="r", label="btf")
plt.plot(df_dp["n"],df_dp["time"],l, c="purple", label="dp")

handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys())
plt.grid()


plt.title(title)
plt.xlabel('n') 
plt.ylabel('s.')  
plt.show()

# %% [markdown]
# ## EXPERIMENTO 3

# %%
df_resultados = pd.read_csv("results/result.csv")
df_resultados = df_resultados[(df_resultados["exp_name"]=="m_exp")]

title = "Experimento 3"
l = ""

plt.xlim(-1,9001)
# plt.ylim(0,0.15)
plt.plot()

for j in range(1,6):
    df_dp = df_resultados[(df_resultados["dataset"]=="m_"+str(j))]
    plt.plot(df_dp['n'], df_dp['time'], label='m = '+str(j*1000))


handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys())
plt.grid()

plt.title(title)
plt.xlabel('n') 
plt.ylabel('s.')  
plt.show()

# %% [markdown]
# ## EXPERIMENTO 4

# %%
df_resultados = pd.read_csv("results/result.csv")
df_resultados = df_resultados[(df_resultados["exp_name"]=="n_exp")]

title = "Experimento 4"
l = ""

# plt.xlim(9,31)
# plt.ylim(0,0.15)
plt.plot()

for j in range(1,6):
    df_dp = df_resultados[(df_resultados["dataset"]=="n_"+str(j))]
    plt.plot(df_dp['m'], df_dp['time'], label='n = '+str(10 + (j*10)))


handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys())
plt.grid()

plt.title(title)
plt.xlabel('Limite De Riesgo') 
plt.ylabel('s.')  
plt.show()

# %% [markdown]
# # EXPERIMENTO DP PEOR QUE BT

# %%
df_resultados = pd.read_csv("results/result.csv")
df_resultados = df_resultados[(df_resultados["dataset"]=="peor_dp")]

title = "BT vs DP"
l = True

plt.xlim(19,24)
plt.ylim(0.015,0.06)
# df_bf = df_resultados[(df_resultados["method"]=="bf")]

df_bt = df_resultados[(df_resultados["method"]=="bt")]

df_bto = df_resultados[(df_resultados["method"]=="bto")]

df_btf = df_resultados[(df_resultados["method"]=="btf")]

df_dp = df_resultados[(df_resultados["method"]=="dp")]

plt.plot()

plt.plot(df_bt["n"],df_bt["time"],l, c="blue", label="bt")
plt.plot(df_bto["n"],df_bto["time"],l, c="green", label="bto")
plt.plot(df_btf["n"],df_btf["time"],l, c="r", label="btf")
plt.plot(df_dp["n"],df_dp["time"],l, c="purple", label="dp")

handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys())
plt.grid()


plt.title(title)
plt.xlabel('n') 
plt.ylabel('s.')  
plt.show()

# %% [markdown]
# ## EXPERIMENTO PARTICULAR BT

# %%
df_resultados = pd.read_csv("results/result.csv")
df_resultados = df_resultados[(df_resultados["dataset"]=="particular_bt")]

title = "Experimento Backtracking"
l = True

plt.xlim(20,40)
# plt.ylim(-0.0001,0.10)
df_bt = df_resultados[(df_resultados["method"]=="bt")]

df_bto = df_resultados[(df_resultados["method"]=="bto")]

df_btf = df_resultados[(df_resultados["method"]=="btf")]


plt.plot()



#puntos
plt.plot(df_bt["n"],df_bt["time"],l, c="blue", label="bt")
plt.plot(df_bto["n"],df_bto["time"],l, c="green", label="bto")
plt.plot(df_btf["n"],df_btf["time"],l, c="r", label="btf")
# plt.plot(df_dp["n"],df_dp["time"],l, c="purple", label="dp")

handles, labels = plt.gca().get_legend_handles_labels()
by_label = dict(zip(labels, handles))
plt.legend(by_label.values(), by_label.keys())
plt.grid()


plt.title(title)
plt.xlabel('n') 
plt.ylabel('s.')  
plt.show()

# %% [markdown]
# ## EXPERIMENTO FB

# %%
df_resultados = pd.read_csv("results/result.csv")
df_bfr = df_resultados[(df_resultados["dataset"]=="random_bf")]
df_bf1 = df_resultados[(df_resultados["dataset"]=="peor_bto_bf")]
df_bf2 = df_resultados[(df_resultados["dataset"]=="peor_btf_bf")]

x = np.linspace(12, 31, 1000)
y = (2**x)*0.000000017

fig, axis = plt.subplots(1,3,figsize=(18,4))

l = "o"
plt.ylabel('segundos')
plt.xlabel('n')
axis[0].plot(x, y, '--')
axis[1].plot(x, y, '--')
axis[2].plot(x, y, '--')

axis[0].plot(df_bfr["n"],df_bfr["time"],l, c="black", label="bf")
axis[1].plot(df_bf1["n"],df_bf1["time"],l, c="black", label="bf")
axis[2].plot(df_bf2["n"],df_bf2["time"],l, c="black", label="bf")
